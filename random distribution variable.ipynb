# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler
from datetime import date
import warnings
warnings.filterwarnings('ignore')

# %%
variable_customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')
variable_customer_df.shape
# Out:
# (9134, 24)

# %%
variable_customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
#  12  Monthly Premium Auto           9134 non-null   int64
#  13  Months Since Last Claim        9134 non-null   int64
#  14  Months Since Policy Inception  9134 non-null   int64
#  15  Number of Open Complaints      9134 non-null   int64
#  16  Number of Policies             9134 non-null   int64
#  17  Policy Type                    9134 non-null   object
#  18  Policy                         9134 non-null   object
#  19  Renew Offer Type               9134 non-null   object
#  20  Sales Channel                  9134 non-null   object
#  21  Total Claim Amount             9134 non-null   float64
#  22  Vehicle Class                  9134 non-null   object
#  23  Vehicle Size                   9134 non-null   object
# dtypes: float64(2), int64(6), object(16)
# memory usage: 1.7+ MB

# %%
variable_customer_df.value_counts()
# Out:
# Customer  State       Customer Lifetime Value  Response  Coverage  Education             Effective To Date  EmploymentStatus  Gender  Income  Location Code  Marital Status  Monthly Premium Auto  Months Since Last Claim  Months Since Policy Inception  Number of Open Complaints  Number of Policies  Policy Type     Policy        Renew Offer Type  Sales Channel  Total Claim Amount  Vehicle Class  Vehicle Size
# AA10041   California  7901.744238              No        Basic     High School or Below  2/2/11             Unemployed        M       0       Suburban       Single          113                   35                       83                             0                          5                   Personal Auto   Personal L3   Offer1            Call Center    1258.327804         SUV            Medsize         1
# RL28880   Nevada      7553.225007              No        Basic     Bachelor              2/12/11            Employed          F       69959   Suburban       Divorced        63                    9                        3                              0                          2                   Personal Auto   Personal L3   Offer1            Branch         401.838921          Two-Door Car   Medsize         1
# RK63095   California  3122.984111              No        Extended  College               1/1/11             Employed          M       72916   Suburban       Single          80                    25                       72                             0                          1                   Personal Auto   Personal L3   Offer2            Web            384.000000          Two-Door Car   Medsize         1
# RK76184   Arizona     2159.251473              No        Basic     College               2/7/11             Unemployed        M       0       Suburban       Married         61                    9                        39                             0                          1                   Personal Auto   Personal L3   Offer2            Web            292.800000          Four-Door Car  Medsize         1
# RK81706   Arizona     7388.733207              No        Extended  College               2/24/11            Unemployed        F       0       Suburban       Married         97                    31                       24                             0                          3                   Personal Auto   Personal L3   Offer4            Call Center    638.371157          Four-Door Car  Medsize         1
#                                                                                                                                                                                                                                                                                                                                                                                                                            ..
# IR78670   California  8719.125849              No        Premium   Bachelor              2/15/11            Unemployed        M       0       Suburban       Married         116                   7                        73                             1                          7                   Personal Auto   Personal L3   Offer2            Branch         556.800000          Four-Door Car  Large           1
# IR74017   Oregon      5320.614976              No        Extended  College               1/21/11            Employed          F       32116   Rural          Married         132                   10                       42                             0                          1                   Personal Auto   Personal L3   Offer4            Call Center    277.351026          SUV            Medsize         1
# IR73545   Oregon      13727.799720             Yes       Extended  College               1/8/11             Unemployed        M       0       Suburban       Single          126                   12                       4                              0                          2                   Personal Auto   Personal L2   Offer1            Agent          604.800000          SUV            Medsize         1
# IR62720   Nevada      6842.580052              No        Extended  Bachelor              2/19/11            Disabled          M       25259   Suburban       Married         87                    18                       8                              0                          9                   Personal Auto   Personal L1   Offer3            Agent          417.600000          Four-Door Car  Medsize         1
# ZZ97035   California  20714.940430             No        Extended  College               2/1/11             Unemployed        M       0       Suburban       Single          203                   20                       66                             0                          2                   Corporate Auto  Corporate L1  Offer1            Branch         2027.724442         Luxury Car     Small           1
# Length: 9134, dtype: int64

# %%
variable_customer_df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# 0                             5                         0                   1
# 1                            42                         0                   8
# 2                            38                         0                   2
# 3                            65                         0                   7
# 4                            44                         0                   1
#
#       Policy Type        Policy  Renew Offer Type  Sales Channel  \
# 0  Corporate Auto  Corporate L3            Offer1          Agent
# 1   Personal Auto   Personal L3            Offer3          Agent
# 2   Personal Auto   Personal L3            Offer1          Agent
# 3  Corporate Auto  Corporate L2            Offer1    Call Center
# 4   Personal Auto   Personal L1            Offer1          Agent
#
#   Total Claim Amount  Vehicle Class Vehicle Size
# 0         384.811147   Two-Door Car      Medsize
# 1        1131.464935  Four-Door Car      Medsize
# 2         566.472247   Two-Door Car      Medsize
# 3         529.881344            SUV      Medsize
# 4         138.130879  Four-Door Car      Medsize
#
# [5 rows x 24 columns]

# %%
variable_customer_df.isna().sum()/len(variable_customer_df)
# Out:
# Customer                         0.0
# State                            0.0
# Customer Lifetime Value          0.0
# Response                         0.0
# Coverage                         0.0
# Education                        0.0
# Effective To Date                0.0
# EmploymentStatus                 0.0
# Gender                           0.0
# Income                           0.0
# Location Code                    0.0
# Marital Status                   0.0
# Monthly Premium Auto             0.0
# Months Since Last Claim          0.0
# Months Since Policy Inception    0.0
# Number of Open Complaints        0.0
# Number of Policies               0.0
# Policy Type                      0.0
# Policy                           0.0
# Renew Offer Type                 0.0
# Sales Channel                    0.0
# Total Claim Amount               0.0
# Vehicle Class                    0.0
# Vehicle Size                     0.0
# dtype: float64

# %% [markdown]
# as we can see here there are no Nan values in the dataset.

# %% [markdown]
# here we are snake casing the column heads

# %%
def fe8 (x:str):
    x = x.replace(" ","_")
    x = x.replace("/", "_")
    return x.lower()

variable_customer_df.columns = list(map(fe8, variable_customer_df.columns))
variable_customer_df
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  ...  \
# 0     Bachelor           2/24/11         Employed      F   56274  ...
# 1     Bachelor           1/31/11       Unemployed      F       0  ...
# 2     Bachelor           2/19/11         Employed      F   48767  ...
# 3     Bachelor           1/20/11       Unemployed      M       0  ...
# 4     Bachelor            2/3/11         Employed      M   43836  ...
# ...        ...               ...              ...    ...     ...  ...
# 9129  Bachelor           2/10/11         Employed      M   71941  ...
# 9130   College           2/12/11         Employed      F   21604  ...
# 9131  Bachelor            2/6/11       Unemployed      M       0  ...
# 9132   College            2/3/11         Employed      M   21941  ...
# 9133   College           2/14/11       Unemployed      M       0  ...
#
#      months_since_policy_inception number_of_open_complaints  \
# 0                                5                         0
# 1                               42                         0
# 2                               38                         0
# 3                               65                         0
# 4                               44                         0
# ...                            ...                       ...
# 9129                            89                         0
# 9130                            28                         0
# 9131                            37                         3
# 9132                             3                         0
# 9133                            90                         0
#
#       number_of_policies     policy_type        policy  renew_offer_type  \
# 0                      1  Corporate Auto  Corporate L3            Offer1
# 1                      8   Personal Auto   Personal L3            Offer3
# 2                      2   Personal Auto   Personal L3            Offer1
# 3                      7  Corporate Auto  Corporate L2            Offer1
# 4                      1   Personal Auto   Personal L1            Offer1
# ...                  ...             ...           ...               ...
# 9129                   2   Personal Auto   Personal L1            Offer2
# 9130                   1  Corporate Auto  Corporate L3            Offer1
# 9131                   2  Corporate Auto  Corporate L2            Offer1
# 9132                   3   Personal Auto   Personal L2            Offer3
# 9133                   1  Corporate Auto  Corporate L3            Offer4
#
#       sales_channel total_claim_amount  vehicle_class vehicle_size
# 0             Agent         384.811147   Two-Door Car      Medsize
# 1             Agent        1131.464935  Four-Door Car      Medsize
# 2             Agent         566.472247   Two-Door Car      Medsize
# 3       Call Center         529.881344            SUV      Medsize
# 4             Agent         138.130879  Four-Door Car      Medsize
# ...             ...                ...            ...          ...
# 9129            Web         198.234764  Four-Door Car      Medsize
# 9130         Branch         379.200000  Four-Door Car      Medsize
# 9131         Branch         790.784983  Four-Door Car      Medsize
# 9132         Branch         691.200000  Four-Door Car        Large
# 9133    Call Center         369.600000   Two-Door Car      Medsize
#
# [9134 rows x 24 columns]

# %% [markdown]
# changing the format of the date column

# %%
variable_customer_df['effective_to_date'] = pd.to_datetime(variable_customer_df['effective_to_date'], errors='coerce') 
variable_customer_df[['effective_to_date']]
# Out:
#      effective_to_date
# 0           2011-02-24
# 1           2011-01-31
# 2           2011-02-19
# 3           2011-01-20
# 4           2011-02-03
# ...                ...
# 9129        2011-02-10
# 9130        2011-02-12
# 9131        2011-02-06
# 9132        2011-02-03
# 9133        2011-02-14
#
# [9134 rows x 1 columns]

# %% [markdown]
# define a function that separate the discrete from the continuous

# %%
nums = variable_customer_df.select_dtypes(np.number)

def discrete_continuous(df):
    d_lst = []
    c_lst = []
    for col in df.columns:
        if len(df[col].unique()) < (df.shape[0] * 0.03):
            d_lst.append(col)
        else:
            c_lst.append(col)

    continuous_df = df[c_lst]
    discrete_df = df[d_lst]
    return continuous_df, discrete_df 

continuous_df, discrete_df = discrete_continuous(nums)

# %%
continuous_df
# Out:
#       customer_lifetime_value  income  total_claim_amount
# 0                 2763.519279   56274          384.811147
# 1                 6979.535903       0         1131.464935
# 2                12887.431650   48767          566.472247
# 3                 7645.861827       0          529.881344
# 4                 2813.692575   43836          138.130879
# ...                       ...     ...                 ...
# 9129             23405.987980   71941          198.234764
# 9130              3096.511217   21604          379.200000
# 9131              8163.890428       0          790.784983
# 9132              7524.442436   21941          691.200000
# 9133              2611.836866       0          369.600000
#
# [9134 rows x 3 columns]

# %%
discrete_df
# Out:
#       monthly_premium_auto  months_since_last_claim  \
# 0                       69                       32
# 1                       94                       13
# 2                      108                       18
# 3                      106                       18
# 4                       73                       12
# ...                    ...                      ...
# 9129                    73                       18
# 9130                    79                       14
# 9131                    85                        9
# 9132                    96                       34
# 9133                    77                        3
#
#       months_since_policy_inception  number_of_open_complaints  \
# 0                                 5                          0
# 1                                42                          0
# 2                                38                          0
# 3                                65                          0
# 4                                44                          0
# ...                             ...                        ...
# 9129                             89                          0
# 9130                             28                          0
# 9131                             37                          3
# 9132                              3                          0
# 9133                             90                          0
#
#       number_of_policies
# 0                      1
# 1                      8
# 2                      2
# 3                      7
# 4                      1
# ...                  ...
# 9129                   2
# 9130                   1
# 9131                   2
# 9132                   3
# 9133                   1
#
# [9134 rows x 5 columns]

# %%
# continuous_df = variable_customer_df.select_dtypes(include = float)
# display(continuous_df)
# discrete_df = variable_customer_df.select_dtypes(include = int)
# discrete_df

# %%
corr_matrix1 = continuous_df.corr()
display(corr_matrix1)

plt.figure(figsize = (10,8))
display(sns.heatmap(corr_matrix1, annot = True))

plt.show()
# Out:
#                          customer_lifetime_value    income  total_claim_amount
# customer_lifetime_value                 1.000000  0.024366            0.226451
# income                                  0.024366  1.000000           -0.355254
# total_claim_amount                      0.226451 -0.355254            1.000000
# <AxesSubplot:>

# %%
corr_matrix2 = discrete_df.corr()
display(corr_matrix2)

plt.figure(figsize = (10,8))
display(sns.heatmap(corr_matrix2, annot = True))
plt.show()
# Out:
#                                monthly_premium_auto  months_since_last_claim  \
# monthly_premium_auto                       1.000000                 0.005026
# months_since_last_claim                    0.005026                 1.000000
# months_since_policy_inception              0.020257                -0.042959
# number_of_open_complaints                 -0.013122                 0.005354
# number_of_policies                        -0.011233                 0.009136
#
#                                months_since_policy_inception  \
# monthly_premium_auto                                0.020257
# months_since_last_claim                            -0.042959
# months_since_policy_inception                       1.000000
# number_of_open_complaints                          -0.001158
# number_of_policies                                 -0.013333
#
#                                number_of_open_complaints  number_of_policies
# monthly_premium_auto                           -0.013122           -0.011233
# months_since_last_claim                         0.005354            0.009136
# months_since_policy_inception                  -0.001158           -0.013333
# number_of_open_complaints                       1.000000            0.001498
# number_of_policies                              0.001498            1.000000
# <AxesSubplot:>

# %%
corr_matrix = nums.corr()
plt.figure(figsize = (10,8))
display(sns.heatmap(corr_matrix, annot = True))
plt.show()
# Out:
# <AxesSubplot:>

# %% [markdown]
# assuming the target will still be the total amount claim, we can inferred from those heat maps , that thera re no clear colinearity from the numerical features to the target.

# %%
plt.figure(figsize = (12,8))
for column in continuous_df:
    sns.histplot(nums[column])
    plt.show()

# %%
plt.figure(figsize = (12,8))
for column in discrete_df:
    sns.distplot(nums[column])
    plt.show()

# %% [markdown]
# 9. we can can from the plots that we have outliers in some columns, and some distribution are not well distributed e.g. Income, total claim amount number of complaints.
#
# Monthly premium auto has the outliers

# %%
sns.pairplot(discrete_df)

# %%
plt.figure(figsize = (12,8))
for column in continuous_df:
    sns.boxplot(nums[column])
    plt.show()

# %% [markdown]
# checking for outliers in the continuous variables

# %%
def find_outlier(col):
    q1, q3 = np.percentile(sorted(col), [25, 75])
    iqr = q3 - q1
   
    lower = q1 - (1.5 * iqr)
    whisker = q3 + (1.5 * iqr)
    outliers = [x for x in col if lower or x >= whisker]
    return outliers

tca_outliers = find_outlier(nums['total_claim_amount'])
mpa_outliers = find_outlier(nums['monthly_premium_auto'])

# %%
tca_outliers
mpa_outliers

pd.DataFrame(data = tca_outliers)
# Out:
#                 0
# 0      384.811147
# 1     1131.464935
# 2      566.472247
# 3      529.881344
# 4      138.130879
# ...           ...
# 9129   198.234764
# 9130   379.200000
# 9131   790.784983
# 9132   691.200000
# 9133   369.600000
#
# [9134 rows x 1 columns]

# %%
nums.isna().sum()
# Out:
# customer_lifetime_value          0
# income                           0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# total_claim_amount               0
# dtype: int64

# %% [markdown]
# we have no Nan values

# %% [markdown]
# # LAB random distribution variable

# %% [markdown]
# Get the numerical variables from our dataset.
#
# Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.
#
# Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.

# %%
nums
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# 2                          18                             38
# 3                          18                             65
# 4                          12                             44
# ...                       ...                            ...
# 9129                       18                             89
# 9130                       14                             28
# 9131                        9                             37
# 9132                       34                              3
# 9133                        3                             90
#
#       number_of_open_complaints  number_of_policies  total_claim_amount
# 0                             0                   1          384.811147
# 1                             0                   8         1131.464935
# 2                             0                   2          566.472247
# 3                             0                   7          529.881344
# 4                             0                   1          138.130879
# ...                         ...                 ...                 ...
# 9129                          0                   2          198.234764
# 9130                          0                   1          379.200000
# 9131                          3                   2          790.784983
# 9132                          0                   3          691.200000
# 9133                          0                   1          369.600000
#
# [9134 rows x 8 columns]

# %%
plt.figure(figsize = (15,15))
for column in nums:
    sns.distplot(nums[column], kde= True)
    plt.show()

# %% [markdown]
# from the plots above, we can infer some statements.
#
# - the discrete numericals : those variables will follow a binomial (or Poisson) distribution
#     * number of policies  ==> poisson distribution
#     * number of open complaints  ==> poisson distribution
#     * months since policy inception  ==> binomial distribution
#     * monthly premium auto  ==> poisson distribution
#     * months since last claim  ==> binomial distribution
#
#
# - the continuous numericals : those variables will follow a normal distribution
#     * income
#     * total_claim_amount
#     * customer_lifetime_value
#
# they all fit the theoritical distributions

# %% [markdown]
# Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.

# %%
# def dist_plots(df):
#     for column in df.columns:
#         sns.distplot(x=column, data=df, kde=True)
#         plt.show()
#     return

# %%
from sklearn.preprocessing import StandardScaler

transformer = StandardScaler().fit(nums)
nums_stand = transformer.transform(nums)
nums_stand_df = pd.DataFrame(nums_stand)

plt.figure(figsize = (15,15))
for column in nums_stand_df:
    sns.distplot(nums_stand_df[column], kde= True)
    plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

transformer2 = MinMaxScaler().fit(nums)
nums_minmax = transformer.transform(nums)
nums_minmax_df = pd.DataFrame(nums_minmax)

plt.figure(figsize = (15,15))
for column in nums_minmax_df:
    sns.distplot(nums_minmax_df[column], kde= True)
    plt.show()

# %%
X = nums.drop(['total_claim_amount'], axis = 1)
y = nums['total_claim_amount']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# %% [markdown]
# # standardize scaler

# %%
from sklearn.preprocessing import StandardScaler

transformer = StandardScaler().fit(X_train)
X_train_standardized = transformer.transform(X_train)
X_test_standardized = transformer.transform(X_test)

# %% [markdown]
# # minmax scaler

# %%
from sklearn.preprocessing import MinMaxScaler

transformer2 = MinMaxScaler().fit(X_train)
X_train_minmax = transformer.transform(X_train)
X_test_minmax = transformer.transform(X_test)

# %% [markdown]
# # log transform

# %%
X_train_log = np.log(X_train)
X_test_log = np.log(X_test)

X_train_log
# Out:
#       customer_lifetime_value     income  monthly_premium_auto  \
# 7706                 8.091063  10.158905              4.406719
# 779                  9.334161  11.280615              4.553877
# 8189                 8.744241   9.522374              4.442651
# 1942                 8.365716  11.102413              4.672829
# 459                  9.221357   9.664723              4.499810
# ...                       ...        ...                   ...
# 350                  8.957071  10.078575              4.663439
# 79                  10.971066  11.023878              5.225747
# 8039                 8.626526   9.314430              4.290459
# 6936                 8.314515  10.052166              4.672829
# 5640                 8.342370  10.328690              4.663439
#
#       months_since_last_claim  months_since_policy_inception  \
# 7706                 2.302585                       4.234107
# 779                  3.332205                       4.110874
# 8189                 3.367296                       3.610918
# 1942                     -inf                       4.304065
# 459                  3.295837                       3.610918
# ...                       ...                            ...
# 350                  2.890372                       4.343805
# 79                       -inf                       3.401197
# 8039                 3.258097                       3.912023
# 6936                 3.433987                       4.094345
# 5640                 2.564949                       3.044522
#
#       number_of_open_complaints  number_of_policies
# 7706                       -inf            0.000000
# 779                    1.098612            0.693147
# 8189                       -inf            1.098612
# 1942                       -inf            0.000000
# 459                        -inf            0.693147
# ...                         ...                 ...
# 350                    0.693147            1.098612
# 79                     0.000000            0.693147
# 8039                       -inf            1.386294
# 6936                       -inf            0.000000
# 5640                       -inf            0.000000
#
# [7307 rows x 7 columns]

# %% [markdown]
# # Linear regression model testing

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
LR = LinearRegression().fit(X_train,y_train)

# %%
predictions = LR.predict(X_train)
print('my r2 score train is:', r2_score(y_train, predictions))

predictions_test = LR.predict(X_test)
print('my r2 score test is:', r2_score(y_test, predictions_test))
# Out:
# my r2 score train is: 0.5288821376636371
# my r2 score test is: 0.4728646269254414

# %% [markdown]
# # KNN regression model testing

# %%
from sklearn.neighbors import KNeighborsRegressor

KNN = KNeighborsRegressor(n_neighbors=5)
KNN.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
score_test = KNN.score(X_test, y_test)
print('my score test is:', score_test)
score_train = KNN.score(X_train, y_train)
print('my score train is:', score_train)
# Out:
# my score test is: 0.21537116687562485
# my score train is: 0.5232388584806118
